# %%
import pickle
with open('recent_tvshows.pkl', 'rb') as f:
    df = pickle.load(f)

# %%
import datetime 
import pandas as pd

pd.set_option('display.max_rows', 1000)
df.sort_values('rate',ascending=False)[['title','rate','initial_release_date','rating_people', 'url']]
# Out:
#           title rate initial_release_date rating_people                                         url
# 2         沉默的真相  9.1           2020-09-16        227942  https://movie.douban.com/subject/33447642/
# 18       十六岁的花季  8.3           2020-08-22         10460   https://movie.douban.com/subject/2155359/
# 34      如此可爱的我们  8.2           2020-07-31         55289  https://movie.douban.com/subject/34801099/
# 20         摩天大楼  8.1           2020-08-19        184247  https://movie.douban.com/subject/33393274/
# 19         此画怎讲  8.1           2020-08-19           768  https://movie.douban.com/subject/35181055/
# 6   重启之极海听雷 第二季  7.9           2020-09-13         64277  https://movie.douban.com/subject/35182499/
# 9        拾光里的我们  7.9           2020-09-04          8565  https://movie.douban.com/subject/27135493/
# 10        平凡的荣耀  7.8           2020-09-04         30731  https://movie.douban.com/subject/30186581/
# ...
